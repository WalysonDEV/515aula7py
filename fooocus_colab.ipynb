# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# ...
# /content
# fatal: destination path 'Fooocus' already exists and is not an empty directory.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0]
# Fooocus version: 2.5.5
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Total VRAM 15095 MB, total RAM 12979 MB
# Set vram state to: HIGH_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# Refiner unloaded.
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# Running on local URL:  http://127.0.0.1:7865
# Running on public URL: https://cb685c5a49c9ee0919.gradio.live
#
# ...

# %%
# !mkdir -p ./models/loras/SDXL/
# !wget -c "https://civitai.com/api/download/models/1236430?type=Model&format=SafeTensor&token=4dfcb09628ce1c34ece0f5b226ca383e" -O "./models/loras/Realism_Lora_By_Stable_yogi_SDXL8.1.safetensors"

# !mkdir -p ./models/checkpoints//SDXL/
# !wget -c "https://civitai.com/api/download/models/1081768?type=Model&format=SafeTensor&size=full&fp=fp16&4dfcb09628ce1c34ece0f5b226ca383e" -O "./models/checkpoints/bigLust_v16.safetensors"

# !mkdir -p ./models/loras/SDXL/
# !wget -c "https://civitai.com/api/download/models/177674?type=Model&format=SafeTensor&token=4dfcb09628ce1c34ece0f5b226ca383e" -O "./models/loras/nudify_xl_lite.safetensors"

# !mkdir -p ./models/loras/SDXL/
# !wget -c "https://civitai.com/api/download/models/165408?type=Model&format=SafeTensor&token=4dfcb09628ce1c34ece0f5b226ca383e" -O "./models/loras/btty.safetensors"
# Out:
# --2025-02-21 19:30:18--  https://civitai.com/api/download/models/1236430?type=Model&format=SafeTensor&token=4dfcb09628ce1c34ece0f5b226ca383e
# Resolving civitai.com (civitai.com)... 172.67.12.143, 104.22.18.237, 104.22.19.237, ...
# Connecting to civitai.com (civitai.com)|172.67.12.143|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/2253457/realismLoraByStable.VvFC.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22Realism_Lora_By_Stable_yogi_SDXL8.1.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250221/us-east-1/s3/aws4_request&X-Amz-Date=20250221T193018Z&X-Amz-SignedHeaders=host&X-Amz-Signature=c13b82be798efc5e1bc1e3f8a77ba2c002264d8a763b2fbfcc789968a72900fa [following]
# ...

# %%
# Diretório onde os modelos do Foocus são armazenados
modelo_diretorio = "/content/Fooocus/models/checkpoints/"

# URL do modelo
url_modelo = "https://civitai.com/api/download/models/253250?type=Model&format=SafeTensor&size=full&fp=fp16"

# Nome do arquivo do modelo
nome_arquivo = "sdxxxl_v30.safetensors"

# Caminho completo para salvar o modelo
caminho_modelo = modelo_diretorio + nome_arquivo

# Baixando o modelo
# !wget -O {caminho_modelo} {url_modelo}

# Verificando se o modelo foi baixado com sucesso
import os
if os.path.exists(caminho_modelo):
    print(f"Modelo {nome_arquivo} adicionado com sucesso ao Foocus!")
else:
    print("Erro ao baixar o modelo. Verifique a URL e tente novamente.")
# Out:
# --2025-02-21 18:20:14--  https://civitai.com/api/download/models/253250?type=Model
# Resolving civitai.com (civitai.com)... 104.22.19.237, 172.67.12.143, 104.22.18.237, ...
# Connecting to civitai.com (civitai.com)|104.22.19.237|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/8215/sdxxxlV30Fp16Vae.w43f.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22sdxxxl_v30.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250221/us-east-1/s3/aws4_request&X-Amz-Date=20250221T182014Z&X-Amz-SignedHeaders=host&X-Amz-Signature=a659610013cb13867c11c44beb6f69048160dac6df53f24905e5a83cd25e1e5c [following]
# ...
